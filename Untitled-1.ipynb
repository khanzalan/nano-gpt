# %%
with open("test.csv", "r",encoding="utf-8") as file:
    text = file.read()

# %%
len(text)
# Out:
# 55778

# %%
print(text[:1000])
# Out:
# text
# "rance ta'en
# As shall with either part's agreement stand?
#
# BAPTISTA:
# Not in my house, Lucentio; for, you know,
# Pitchers have ears, and I have many servants:
# Besides, old Gremio is hearkening still;
# And happily we might be interrupted.
#
# TRANIO:
# Then at my lodging, an it like you:
# There doth my father lie; and there, this night,
# We'll pass the business privately and well.
# Send for your daughter by your servant here:
# My boy shall fetch the scrivener presently.
# The worst is this, that, at so slender warning,
# You are like to have a thin and slender pittance.
#
# BAPTISTA:
# It likes me well. Biondello, hie you home,
# And bid Bianca make her ready straight;
# And, if you will, tell what hath happened,
# Lucentio's father is arrived in Padua,
# And how she's like to be Lucentio's wife.
#
# BIONDELLO:
# I pray the gods she may with all my heart!
#
# TRANIO:
# Dally not with the gods, but get thee gone.
# Signior Baptista, shall I lead the way?
# Welcome! one mess is like to be your cheer:
# Come, sir; we will better

# %%
chars=sorted(list(set(text)))
vocab_size=len(chars)
print("".join(chars))
print(f"Vocab size: {vocab_size}")
# Out:
#  !"',-.:;?ABCDEFGHIJKLMNOPRSTUVWYZabcdefghijklmnopqrstuvwxyz
# Vocab size: 61

# %%
stoi={ch:i for i,ch in enumerate(chars)}
itos={i:ch for i,ch in enumerate(chars)}
encode=lambda s:[stoi[c] for c in s]
decode=lambda l:''.join([itos[i] for i in l])
print(encode("hello world"))
print(decode(encode("hello world")))
# Out:
# [42, 39, 46, 46, 49, 1, 57, 49, 52, 46, 38]
# hello world

# %%
# import tiktoken
# encoding = tiktoken.get_encoding("gpt2")
# encoded = encoding.encode("hello world")
# print(encoded)
# decoded = encoding.decode(encoded)
# print(decoded)

# %%
import torch
data=torch.tensor(encode(text),dtype=torch.long)
print(data.shape,data.dtype)
print(data[:1000])
# Out:
# torch.Size([55778]) torch.int64
# tensor([54, 39, 58, 54,  0,  3, 52, 35, 48, 37, 39,  1, 54, 35,  4, 39, 48,  0,
#         11, 53,  1, 53, 42, 35, 46, 46,  1, 57, 43, 54, 42,  1, 39, 43, 54, 42,
#         39, 52,  1, 50, 35, 52, 54,  4, 53,  1, 35, 41, 52, 39, 39, 47, 39, 48,
#         54,  1, 53, 54, 35, 48, 38, 10,  0,  0, 12, 11, 26, 29, 19, 28, 29, 11,
#          8,  0, 24, 49, 54,  1, 43, 48,  1, 47, 59,  1, 42, 49, 55, 53, 39,  5,
#          1, 22, 55, 37, 39, 48, 54, 43, 49,  9,  1, 40, 49, 52,  5,  1, 59, 49,
#         55,  1, 45, 48, 49, 57,  5,  0, 26, 43, 54, 37, 42, 39, 52, 53,  1, 42,
#         35, 56, 39,  1, 39, 35, 52, 53,  5,  1, 35, 48, 38,  1, 19,  1, 42, 35,
#         56, 39,  1, 47, 35, 48, 59,  1, 53, 39, 52, 56, 35, 48, 54, 53,  8,  0,
#         12, 39, 53, 43, 38, 39, 53,  5,  1, 49, 46, 38,  1, 17, 52, 39, 47, 43,
#         49,  1, 43, 53,  1, 42, 39, 35, 52, 45, 39, 48, 43, 48, 41,  1, 53, 54,
#         43, 46, 46,  9,  0, 11, 48, 38,  1, 42, 35, 50, 50, 43, 46, 59,  1, 57,
#         39,  1, 47, 43, 41, 42, 54,  1, 36, 39,  1, 43, 48, 54, 39, 52, 52, 55,
#         50, 54, 39, 38,  7,  0,  0, 29, 27, 11, 24, 19, 25,  8,  0, 29, 42, 39,
#         48,  1, 35, 54,  1, 47, 59,  1, 46, 49, 38, 41, 43, 48, 41,  5,  1, 35,
#         48,  1, 43, 54,  1, 46, 43, 45, 39,  1, 59, 49, 55,  8,  0, 29, 42, 39,
#         52, 39,  1, 38, 49, 54, 42,  1, 47, 59,  1, 40, 35, 54, 42, 39, 52,  1,
#         46, 43, 39,  9,  1, 35, 48, 38,  1, 54, 42, 39, 52, 39,  5,  1, 54, 42,
#         43, 53,  1, 48, 43, 41, 42, 54,  5,  0, 32, 39,  4, 46, 46,  1, 50, 35,
#         53, 53,  1, 54, 42, 39,  1, 36, 55, 53, 43, 48, 39, 53, 53,  1, 50, 52,
#         43, 56, 35, 54, 39, 46, 59,  1, 35, 48, 38,  1, 57, 39, 46, 46,  7,  0,
#         28, 39, 48, 38,  1, 40, 49, 52,  1, 59, 49, 55, 52,  1, 38, 35, 55, 41,
#         42, 54, 39, 52,  1, 36, 59,  1, 59, 49, 55, 52,  1, 53, 39, 52, 56, 35,
#         48, 54,  1, 42, 39, 52, 39,  8,  0, 23, 59,  1, 36, 49, 59,  1, 53, 42,
#         35, 46, 46,  1, 40, 39, 54, 37, 42,  1, 54, 42, 39,  1, 53, 37, 52, 43,
#         56, 39, 48, 39, 52,  1, 50, 52, 39, 53, 39, 48, 54, 46, 59,  7,  0, 29,
#         42, 39,  1, 57, 49, 52, 53, 54,  1, 43, 53,  1, 54, 42, 43, 53,  5,  1,
#         54, 42, 35, 54,  5,  1, 35, 54,  1, 53, 49,  1, 53, 46, 39, 48, 38, 39,
#         52,  1, 57, 35, 52, 48, 43, 48, 41,  5,  0, 33, 49, 55,  1, 35, 52, 39,
#          1, 46, 43, 45, 39,  1, 54, 49,  1, 42, 35, 56, 39,  1, 35,  1, 54, 42,
#         43, 48,  1, 35, 48, 38,  1, 53, 46, 39, 48, 38, 39, 52,  1, 50, 43, 54,
#         54, 35, 48, 37, 39,  7,  0,  0, 12, 11, 26, 29, 19, 28, 29, 11,  8,  0,
#         19, 54,  1, 46, 43, 45, 39, 53,  1, 47, 39,  1, 57, 39, 46, 46,  7,  1,
#         12, 43, 49, 48, 38, 39, 46, 46, 49,  5,  1, 42, 43, 39,  1, 59, 49, 55,
#          1, 42, 49, 47, 39,  5,  0, 11, 48, 38,  1, 36, 43, 38,  1, 12, 43, 35,
#         48, 37, 35,  1, 47, 35, 45, 39,  1, 42, 39, 52,  1, 52, 39, 35, 38, 59,
#          1, 53, 54, 52, 35, 43, 41, 42, 54,  9,  0, 11, 48, 38,  5,  1, 43, 40,
#          1, 59, 49, 55,  1, 57, 43, 46, 46,  5,  1, 54, 39, 46, 46,  1, 57, 42,
#         35, 54,  1, 42, 35, 54, 42,  1, 42, 35, 50, 50, 39, 48, 39, 38,  5,  0,
#         22, 55, 37, 39, 48, 54, 43, 49,  4, 53,  1, 40, 35, 54, 42, 39, 52,  1,
#         43, 53,  1, 35, 52, 52, 43, 56, 39, 38,  1, 43, 48,  1, 26, 35, 38, 55,
#         35,  5,  0, 11, 48, 38,  1, 42, 49, 57,  1, 53, 42, 39,  4, 53,  1, 46,
#         43, 45, 39,  1, 54, 49,  1, 36, 39,  1, 22, 55, 37, 39, 48, 54, 43, 49,
#          4, 53,  1, 57, 43, 40, 39,  7,  0,  0, 12, 19, 25, 24, 14, 15, 22, 22,
#         25,  8,  0, 19,  1, 50, 52, 35, 59,  1, 54, 42, 39,  1, 41, 49, 38, 53,
#          1, 53, 42, 39,  1, 47, 35, 59,  1, 57, 43, 54, 42,  1, 35, 46, 46,  1,
#         47, 59,  1, 42, 39, 35, 52, 54,  2,  0,  0, 29, 27, 11, 24, 19, 25,  8,
#          0, 14, 35, 46, 46, 59,  1, 48, 49, 54,  1, 57, 43, 54, 42,  1, 54, 42,
#         39,  1, 41, 49, 38, 53,  5,  1, 36, 55, 54,  1, 41, 39, 54,  1, 54, 42,
#         39, 39,  1, 41, 49, 48, 39,  7,  0, 28, 43, 41, 48, 43, 49, 52,  1, 12,
#         35, 50, 54, 43, 53, 54, 35,  5,  1, 53, 42, 35, 46, 46,  1, 19,  1, 46,
#         39, 35, 38,  1, 54, 42, 39,  1, 57, 35, 59, 10,  0, 32, 39, 46, 37, 49,
#         47, 39,  2,  1, 49, 48, 39,  1, 47, 39, 53, 53,  1, 43, 53,  1, 46, 43,
#         45, 39,  1, 54, 49,  1, 36, 39,  1, 59, 49, 55, 52,  1, 37, 42, 39, 39,
#         52,  8,  0, 13, 49, 47, 39,  5,  1, 53, 43, 52,  9,  1, 57, 39,  1, 57,
#         43, 46, 46,  1, 36, 39, 54, 54, 39, 52])

# %%
n=int(0.9*len(data))
train_data=data[:n]
val_data=data[n:]

# %%
block_size=8
train_data[:block_size+1]
x=train_data[:block_size]
y=train_data[1:block_size+1]
for t in range(block_size):
    context=x[:t+1]
    target=y[t]
    print(f"when input is {context} the target: {target}")
# Out:
# when input is tensor([54]) the target: 39
# when input is tensor([54, 39]) the target: 58
# when input is tensor([54, 39, 58]) the target: 54
# when input is tensor([54, 39, 58, 54]) the target: 0
# when input is tensor([54, 39, 58, 54,  0]) the target: 3
# when input is tensor([54, 39, 58, 54,  0,  3]) the target: 52
# when input is tensor([54, 39, 58, 54,  0,  3, 52]) the target: 35
# when input is tensor([54, 39, 58, 54,  0,  3, 52, 35]) the target: 48

# %%
torch.manual_seed(46)
batch_size=4
def get_batch(split):
    data=train_data if split=='train' else val_data
    ix=torch.randint(len(data)-block_size,(batch_size,))
    x=torch.stack([data[i:i+block_size]for i in ix])
    y=torch.stack([data[i+1:i+block_size+1]for i in ix])
    return x,y
xb,yb=get_batch('train')
print("inputs:")
print(xb.shape)
print(xb)
print("targets:")
print(yb.shape)
print(yb)   

for b in range(batch_size):
    for t in range(block_size):
        context=xb[b,:t+1]
        target=yb[b,t]
        print(f"when input is {context.tolist()} the target: {target}")
# Out:
# inputs:
# torch.Size([4, 8])
# tensor([[36, 35, 37, 45,  9,  1, 35, 48],
#         [ 1, 49, 40,  1, 59, 49, 55,  7],
#         [35, 52, 39,  1, 53, 57, 39, 35],
#         [35, 41, 39,  7,  0,  0, 11, 14]])
# targets:
# torch.Size([4, 8])
# tensor([[35, 37, 45,  9,  1, 35, 48, 38],
#         [49, 40,  1, 59, 49, 55,  7,  0],
#         [52, 39,  1, 53, 57, 39, 35, 52],
#         [41, 39,  7,  0,  0, 11, 14, 27]])
# when input is [36] the target: 35
# when input is [36, 35] the target: 37
# when input is [36, 35, 37] the target: 45
# when input is [36, 35, 37, 45] the target: 9
# when input is [36, 35, 37, 45, 9] the target: 1
# when input is [36, 35, 37, 45, 9, 1] the target: 35
# when input is [36, 35, 37, 45, 9, 1, 35] the target: 48
# when input is [36, 35, 37, 45, 9, 1, 35, 48] the target: 38
# when input is [1] the target: 49
# when input is [1, 49] the target: 40
# when input is [1, 49, 40] the target: 1
# when input is [1, 49, 40, 1] the target: 59
# when input is [1, 49, 40, 1, 59] the target: 49
# when input is [1, 49, 40, 1, 59, 49] the target: 55
# when input is [1, 49, 40, 1, 59, 49, 55] the target: 7
# when input is [1, 49, 40, 1, 59, 49, 55, 7] the target: 0
# when input is [35] the target: 52
# when input is [35, 52] the target: 39
# when input is [35, 52, 39] the target: 1
# when input is [35, 52, 39, 1] the target: 53
# when input is [35, 52, 39, 1, 53] the target: 57
# when input is [35, 52, 39, 1, 53, 57] the target: 39
# when input is [35, 52, 39, 1, 53, 57, 39] the target: 35
# when input is [35, 52, 39, 1, 53, 57, 39, 35] the target: 52
# when input is [35] the target: 41
# when input is [35, 41] the target: 39
# when input is [35, 41, 39] the target: 7
# when input is [35, 41, 39, 7] the target: 0
# when input is [35, 41, 39, 7, 0] the target: 0
# when input is [35, 41, 39, 7, 0, 0] the target: 11
# when input is [35, 41, 39, 7, 0, 0, 11] the target: 14
# when input is [35, 41, 39, 7, 0, 0, 11, 14] the target: 27

# %%
print(xb)
# Out:
# tensor([[36, 35, 37, 45,  9,  1, 35, 48],
#         [ 1, 49, 40,  1, 59, 49, 55,  7],
#         [35, 52, 39,  1, 53, 57, 39, 35],
#         [35, 41, 39,  7,  0,  0, 11, 14]])

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
torch.manual_seed(1337)

class BigramLanguageModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, vocab_size)

    def forward(self, idx, targets=None):

       
        logits = self.token_embedding_table(idx) # (B,T,C)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        for _ in range(max_new_tokens):
            logits, loss = self(idx)
            logits = logits[:, -1, :]
            probs = F.softmax(logits, dim=-1) # (B, C)
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

m = BigramLanguageModel(vocab_size)
logits, loss = m(xb, yb)
print(logits.shape)
print(loss)

print(decode(m.generate(idx = torch.zeros((1, 1), dtype=torch.long), max_new_tokens=100)[0].tolist()))
# Out:
# torch.Size([32, 61])
# tensor(4.6076, grad_fn=<NllLossBackward0>)
#
# RkY
# ERi-ozLJgJ
# AZnUs--IJ'fjt IbzpUFJqB'!k!mio;q.G.hIDE; nBti'mJc:qBwjW-u
# s-uId-o-uD nnn!.?IH,:CNTF F

# %%
optimizer = torch.optim.AdamW(m.parameters(), lr=1e-3)

# %%
batch_size = 32
for steps in range(10000):
    xb,yb = get_batch('train')
    logits, loss = m(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
print(loss.item())
# Out:
# 2.3062217235565186

# %%
print(decode(m.generate(idx = torch.zeros((1, 1), dtype=torch.long), max_new_tokens=200)[0].tolist()))
# Out:
# Who ar,nortong hysirmetheriensif usiorastre
# xZAPEThond HIRIONTouthe iseellee
#
# Fayorid thortyseavethisepmeswiney thanth my y.
# May y.
# Burs tremive p wis IO:
# Fharusist, ireakeebinndigul s atlso? IO: ty,

# %%
torch.manual_seed(42)
B,T,C=4,8,2
x=torch.randn(B,T,C)
x.shape
# Out:
# torch.Size([4, 8, 2])

# %%
xbow=torch.zeros(B,T,C)
for b in range(B):
    for t in range(T):
        xprev=x[b,:t+1]
        xbow[b,t]=torch.mean(xprev,0)

# %%
x[0],xbow[0]
# Out:
# (tensor([[ 1.9269,  1.4873],
#          [ 0.9007, -2.1055],
#          [ 0.6784, -1.2345],
#          [-0.0431, -1.6047],
#          [-0.7521,  1.6487],
#          [-0.3925, -1.4036],
#          [-0.7279, -0.5594],
#          [-0.7688,  0.7624]]),
#  tensor([[ 1.9269,  1.4873],
#          [ 1.4138, -0.3091],
#          [ 1.1687, -0.6176],
#          [ 0.8657, -0.8644],
#          [ 0.5422, -0.3617],
#          [ 0.3864, -0.5354],
#          [ 0.2272, -0.5388],
#          [ 0.1027, -0.3762]]))

# %%
torch.manual_seed(42)
a=torch.ones(3,3)
a=a/torch.sum(a,1,keepdim=True)
b=torch.randint(0,10,(3,2)).float()
c=a@b
print('a=')
print(a)
print('b=')
print(b)
print("--")
print('c=')
print(c)
# Out:
# a=
# tensor([[0.3333, 0.3333, 0.3333],
#         [0.3333, 0.3333, 0.3333],
#         [0.3333, 0.3333, 0.3333]])
# b=
# tensor([[2., 7.],
#         [6., 4.],
#         [6., 5.]])
# --
# c=
# tensor([[4.6667, 5.3333],
#         [4.6667, 5.3333],
#         [4.6667, 5.3333]])
# tensor([[1., 0., 0.],
#         [1., 1., 0.],
#         [1., 1., 1.]])

# %%
wei=torch.tril(torch.ones(T,T))
wei=wei/wei.sum(1,keepdim=True)
xbow2= wei@x
torch.allclose(xbow,xbow2)
# Out:
# True

# %%
xbow[0],xbow2[0]
# Out:
# (tensor([[ 1.9269,  1.4873],
#          [ 1.4138, -0.3091],
#          [ 1.1687, -0.6176],
#          [ 0.8657, -0.8644],
#          [ 0.5422, -0.3617],
#          [ 0.3864, -0.5354],
#          [ 0.2272, -0.5388],
#          [ 0.1027, -0.3762]]),
#  tensor([[ 1.9269,  1.4873],
#          [ 1.4138, -0.3091],
#          [ 1.1687, -0.6176],
#          [ 0.8657, -0.8644],
#          [ 0.5422, -0.3617],
#          [ 0.3864, -0.5354],
#          [ 0.2272, -0.5388],
#          [ 0.1027, -0.3762]]))

# %%
tril=torch.tril(torch.ones(T,T))
wei=torch.zeros((T,T))
wei=wei.masked_fill(tril==0,float('-inf'))
wei=F.softmax(wei,dim=-1)
xbow3=wei@x
torch.allclose(xbow,xbow3)
# Out:
# True

# %%
xbow3[0]
# Out:
# tensor([[ 1.9269,  1.4873],
#         [ 1.4138, -0.3091],
#         [ 1.1687, -0.6176],
#         [ 0.8657, -0.8644],
#         [ 0.5422, -0.3617],
#         [ 0.3864, -0.5354],
#         [ 0.2272, -0.5388],
#         [ 0.1027, -0.3762]])

# %%
torch.manual_seed(42)
B,T,C=4,8,32
x=torch.randn(B,T,C)
head_size=16
key=nn.Linear(C,head_size,bias=False)
query=nn.Linear(C,head_size,bias=False)
value=nn.Linear(C,head_size,bias=False)
k=key(x)
q=query(x)
wei=q@k.transpose(-2,-1)*(head_size**-0.5)
tril=torch.tril(torch.ones(T,T))
# wei=torch.zeros((T,T))
wei=wei.masked_fill(tril==0,float('-inf'))
wei=F.softmax(wei,dim=-1)
# out=wei@x
v=value(x)
out=wei@v
out.shape
# Out:
# torch.Size([4, 8, 16])

# %%
wei[0]
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.4106, 0.5894, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3657, 0.2283, 0.4061, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2168, 0.2759, 0.2204, 0.2870, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2553, 0.1697, 0.1548, 0.2341, 0.1861, 0.0000, 0.0000, 0.0000],
#         [0.1318, 0.2060, 0.1405, 0.1917, 0.1949, 0.1351, 0.0000, 0.0000],
#         [0.2137, 0.0978, 0.2374, 0.1025, 0.1418, 0.0838, 0.1230, 0.0000],
#         [0.0852, 0.1047, 0.0824, 0.1376, 0.1015, 0.1900, 0.1780, 0.1206]],
#        grad_fn=<SelectBackward0>)

# %%
wei.var()
# Out:
# tensor(0.0541, grad_fn=<VarBackward0>)

# %%
class LayerNorm1d: # (used to be BatchNorm1d)

  def __init__(self, dim, eps=1e-5, momentum=0.1):
    self.eps = eps
    self.gamma = torch.ones(dim)
    self.beta = torch.zeros(dim)

  def __call__(self, x):
    # calculate the forward pass
    xmean = x.mean(1, keepdim=True) # batch mean
    xvar = x.var(1, keepdim=True) # batch variance
    xhat = (x - xmean) / torch.sqrt(xvar + self.eps) # normalize to unit variance
    self.out = self.gamma * xhat + self.beta
    return self.out

  def parameters(self):
    return [self.gamma, self.beta]

torch.manual_seed(1337)
module = LayerNorm1d(100)
x = torch.randn(32, 100) # batch size 32 of 100-dimensional vectors
x = module(x)
x.shape
# Out:
# torch.Size([32, 100])
